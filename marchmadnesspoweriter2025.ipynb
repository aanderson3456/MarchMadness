# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import datetime



# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/march-machine-learning-mania-2025/Conferences.csv
# /kaggle/input/march-machine-learning-mania-2025/SeedBenchmarkStage1.csv
# /kaggle/input/march-machine-learning-mania-2025/WNCAATourneyDetailedResults.csv
# /kaggle/input/march-machine-learning-mania-2025/WRegularSeasonCompactResults.csv
# /kaggle/input/march-machine-learning-mania-2025/MNCAATourneySeedRoundSlots.csv
# /kaggle/input/march-machine-learning-mania-2025/MRegularSeasonDetailedResults.csv
# /kaggle/input/march-machine-learning-mania-2025/MNCAATourneyCompactResults.csv
# /kaggle/input/march-machine-learning-mania-2025/MGameCities.csv
# /kaggle/input/march-machine-learning-mania-2025/WSecondaryTourneyCompactResults.csv
# /kaggle/input/march-machine-learning-mania-2025/WGameCities.csv
# /kaggle/input/march-machine-learning-mania-2025/MSeasons.csv
# /kaggle/input/march-machine-learning-mania-2025/WNCAATourneySlots.csv
# /kaggle/input/march-machine-learning-mania-2025/MSecondaryTourneyTeams.csv
# ...

# %%
MTeams = pd.read_csv("/kaggle/input/march-machine-learning-mania-2025/MTeams.csv")
MIDtoName = MTeams.set_index("TeamID")["TeamName"].to_dict()
MNametoID = MTeams.set_index("TeamName")["TeamID"].to_dict()
WTeams = pd.read_csv("/kaggle/input/march-machine-learning-mania-2025/WTeams.csv")
WIDtoName = WTeams.set_index("TeamID")["TeamName"].to_dict()
WNametoID = WTeams.set_index("TeamName")["TeamID"].to_dict()


MGames = pd.read_csv("/kaggle/input/march-machine-learning-mania-2025/MRegularSeasonCompactResults.csv")
WGames = pd.read_csv("/kaggle/input/march-machine-learning-mania-2025/WRegularSeasonCompactResults.csv")

#build matrix for power iteration
Mlen = MTeams.shape[0]
Mmat3 = []
Mmat5 = []
for i in range(Mlen):
    Mmat3.append(list(np.zeros((Mlen,), dtype=int)))
    Mmat5.append(list(np.zeros((Mlen,), dtype=int)))

Wlen = MTeams.shape[0]
#seems to be missing IDs in WTeams
Wmat3 = []
Wmat5 = []
for i in range(Wlen):
    Wmat3.append(list(np.zeros((Wlen,), dtype=int)))
    Wmat5.append(list(np.zeros((Wlen,), dtype=int)))

print("done w cell at" ,datetime.datetime.now().time())
# Out:
# done w cell at 19:19:48.148348

# %%
M25 = MGames[MGames['Season']==2025]
for index, row in M25.iterrows():
    #print(f"Index: {index}, WTeamID: {row['WTeamID']}, WScore: {row['WScore']}, LTeamID: {row['LTeamID']}, LScore: {row['LScore']}")
    winnerID = row['WTeamID']
    loserID = row['LTeamID']
    winnerLoc = winnerID - 1101
    loserLoc = loserID - 1101
    diff = row['WScore'] - row['LScore']
    Mmat5[winnerLoc][loserLoc] += 5*diff
    Mmat3[winnerLoc][loserLoc] += 3*diff


W25 = WGames[WGames['Season']==2025]
for index, row in W25.iterrows():
    #print(f"Index: {index}, WTeamID: {row['WTeamID']}, WScore: {row['WScore']}, LTeamID: {row['LTeamID']}, LScore: {row['LScore']}")
    winnerID = row['WTeamID']
    loserID = row['LTeamID']
    winnerLoc = winnerID - 3101
    loserLoc = loserID - 3101
    diff = row['WScore'] - row['LScore']
    Wmat5[winnerLoc][loserLoc] += 5*diff
    Wmat3[winnerLoc][loserLoc] += 3*diff


M24 = MGames[MGames['Season']==2024]
for index, row in M24.iterrows():
    #print(f"Index: {index}, WTeamID: {row['WTeamID']}, WScore: {row['WScore']}, LTeamID: {row['LTeamID']}, LScore: {row['LScore']}")
    winnerID = row['WTeamID']
    loserID = row['LTeamID']
    winnerLoc = winnerID - 1101
    loserLoc = loserID - 1101
    diff = row['WScore'] - row['LScore']
    Mmat5[winnerLoc][loserLoc] += 2*diff
    Mmat3[winnerLoc][loserLoc] += 2*diff


W24 = WGames[WGames['Season']==2024]
for index, row in W24.iterrows():
    #print(f"Index: {index}, WTeamID: {row['WTeamID']}, WScore: {row['WScore']}, LTeamID: {row['LTeamID']}, LScore: {row['LScore']}")
    winnerID = row['WTeamID']
    loserID = row['LTeamID']
    winnerLoc = winnerID - 3101
    loserLoc = loserID - 3101
    diff = row['WScore'] - row['LScore']
    Wmat5[winnerLoc][loserLoc] += 2*diff
    Wmat3[winnerLoc][loserLoc] += 2*diff

print("done w cell at" ,datetime.datetime.now().time())
# Out:
# done w cell at 19:19:55.282507

# %%
M253 = MGames[MGames['Season']==2025]
for index, row in M25.iterrows():
    #print(f"Index: {index}, WTeamID: {row['WTeamID']}, WScore: {row['WScore']}, LTeamID: {row['LTeamID']}, LScore: {row['LScore']}")
    winnerID = row['WTeamID']
    loserID = row['LTeamID']
    winnerLoc = winnerID - 1101
    loserLoc = loserID - 1101
    diff = row['WScore'] - row['LScore']
    Mmat[winnerLoc][loserLoc] += 3*diff

W253 = WGames[WGames['Season']==2025]
for index, row in W25.iterrows():
    #print(f"Index: {index}, WTeamID: {row['WTeamID']}, WScore: {row['WScore']}, LTeamID: {row['LTeamID']}, LScore: {row['LScore']}")
    winnerID = row['WTeamID']
    loserID = row['LTeamID']
    winnerLoc = winnerID - 3101
    loserLoc = loserID - 3101
    diff = row['WScore'] - row['LScore']
    Wmat[winnerLoc][loserLoc] += 3*diff


print("done w cell at" ,datetime.datetime.now().time())
# Out:
# done w cell at 19:20:00.284732

# %%
#from https://andrewcharlesjones.github.io/journal/power-iteration.html
num_iters = 100
A = np.array(Mmat5)
# Starting vector
b = np.random.rand(A.shape[0])
# Power iteration
for ii in range(num_iters):   
    # Project
    bnew = A @ b    
    # Normalize
    b = bnew / np.linalg.norm(bnew, ord=2)
    
MpowRanks5 = dict()
for i in range(len(b)):
    MpowRanks5[MIDtoName[i+1101]] = b[i]
    #print('team',MIDtoName[i+1101],'value',b[i]*1000)

A = np.array(Wmat5)
# Starting vector
b = np.random.rand(A.shape[0])
# Power iteration
for ii in range(num_iters):   
    # Project
    bnew = A @ b    
    # Normalize
    b = bnew / np.linalg.norm(bnew, ord=2)

WpowRanks5 = dict()
for i in range(len(b)):
    try:
        WpowRanks5[WIDtoName[i+3101]] = b[i]
        #print('team',WIDtoName[i+3101],'value',b[i]*1000)
    except:
        print("looks like",i+3101,"not a WteamID")

#from https://andrewcharlesjones.github.io/journal/power-iteration.html
num_iters = 100
A = np.array(Mmat3)
# Starting vector
b = np.random.rand(A.shape[0])
# Power iteration
for ii in range(num_iters):   
    # Project
    bnew = A @ b    
    # Normalize
    b = bnew / np.linalg.norm(bnew, ord=2)
    
MpowRanks3 = dict()
for i in range(len(b)):
    MpowRanks3[MIDtoName[i+1101]] = b[i]
    #print('team',MIDtoName[i+1101],'value',b[i]*1000)

A = np.array(Wmat3)
# Starting vector
b = np.random.rand(A.shape[0])
# Power iteration
for ii in range(num_iters):   
    # Project
    bnew = A @ b    
    # Normalize
    b = bnew / np.linalg.norm(bnew, ord=2)

WpowRanks3 = dict()
for i in range(len(b)):
    try:
        WpowRanks3[WIDtoName[i+3101]] = b[i]
        #print('team',WIDtoName[i+3101],'value',b[i]*1000)
    except:
        print("looks like",i+3101,"not a WteamID")
print("done w cell at" ,datetime.datetime.now().time())
# Out:
# looks like 3154 not a WteamID
# looks like 3440 not a WteamID
# looks like 3154 not a WteamID
# looks like 3440 not a WteamID
# done w cell at 19:20:03.955753

# %%
def simGame(t1name,t2name,gender = 'M',version = 5):
    if gender == "M":
        diff = MpowRanks5[t1name] - MpowRanks5[t2name]
        sumt = MpowRanks5[t1name] + MpowRanks5[t2name]
        prob = 0.5 + 0.5*(diff/sumt)
        #print(t1name,'wins w prob',prob)
    if gender == "W":
        diff = WpowRanks[t1name] - WpowRanks[t2name]
        sumt = WpowRanks[t1name] + WpowRanks[t2name]
        prob = 0.5 + 0.5*(diff/sumt)
        #print(t1name,'wins w prob',prob)
    if version == 3:
        if gender == "M":
            diff = MpowRanks3[t1name] - MpowRanks3[t2name]
            sumt = MpowRanks3[t1name] + MpowRanks3[t2name]
            prob = 0.5 + 0.5*(diff/sumt)
            #print(t1name,'wins w prob',prob)
        if gender == "W":
            diff = WpowRanks3[t1name] - WpowRanks3[t2name]
            sumt = WpowRanks3[t1name] + WpowRanks3[t2name]
            prob = 0.5 + 0.5*(diff/sumt)
            #print(t1name,'wins w prob',prob)
    return prob
print("done w cell at" ,datetime.datetime.now().time())
# Out:
# done w cell at 19:20:09.472377

# %%
for i in [3,5]:
    print(simGame("Marquette","New Mexico","M",i))

for i in [3,5]:
    print(simGame("McNeese St","Clemson","M",i))
    
for i in [3,5]:
    print(simGame("Louisville","Creighton","M",i))

    
for i in [3,5]:
    print(simGame("South Carolina","UCLA","W",i))
# Out:
# 0.6847230714356285
# 0.6855117139764723
# 0.15127313808465614
# 0.14572744179242786
# 0.44249904440337806
# 0.48157336244139676
# 0.6148979855506461
# 0.6081111605933303

# %%
names = pd.read_csv("/kaggle/input/march-machine-learning-mania-2025/MTeams.csv")

names = names["TeamName"][1:27]
print(names)
# Out:
# 1           Air Force
# 2               Akron
# 3             Alabama
# 4         Alabama A&M
# 5          Alabama St
# 6         SUNY Albany
# 7           Alcorn St
# 8        Alliant Intl
# 9       American Univ
# 10     Appalachian St
# 11            Arizona
# 12         Arizona St
# 13    Ark Little Rock
# 14     Ark Pine Bluff
# 15           Arkansas
# 16        Arkansas St
# 17       Armstrong St
# 18               Army
# 19             Auburn
# 20            Augusta
# 21        Austin Peay
# 22            Ball St
# 23             Baylor
# 24            Belmont
# 25    Bethune-Cookman
# 26         Binghamton
# Name: TeamName, dtype: object

# %%
res = pd.read_csv("/kaggle/input/march-machine-learning-mania-2025/SampleSubmissionStage2.csv")
for index, row in res.iterrows():
    year,t1,t2 = row["ID"].split("_")
    t1 = int(t1)
    t2 = int(t2)
    #print(f"index {index} row {row}")
    #print(f"year {year} t1 {t1} t2 {t2}")
    if 1101 <= t1 and t1 < 3000:
        t1name = MIDtoName[t1]
        t2name = MIDtoName[t2]
        pred = simGame(t1name,t2name,"M")
        res.iat[index,1] = pred
        #print("at index ",index)
        
    if 3000 < t1:
        t1name = WIDtoName[t1]
        t2name = WIDtoName[t2]
        pred = simGame(t1name,t2name,"W")
        res.iat[index,1] = pred

print("done w cell at" ,datetime.datetime.now().time())
# Out:
# done w cell at 18:48:20.502894

# %%
res.to_csv('outSubmission.csv', index=False)
